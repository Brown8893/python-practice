# %% [markdown]
# <a href="https://colab.research.google.com/github/Brown8893/python-practice/blob/master/python_300_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#我的python練習(Ch3-3.1)
import math # import Math module to use the math functions
 
# Test algebraic functions
print("exp(4.0) =", math.exp(1))
print("log(8.25) =", math.log(math.e))
print("log10(30, 50) =", math.log(10, 10))
print("sqrt(6.7) =", math.sqrt(4.0))
 
# Test trigonometric functions
print("sin(PI / 2) =", math.sin(math.pi / 2))
print("cos(PI / 2) =", math.cos(math.pi / 2))
print("tan(PI / 2) =", math.tan(math.pi / 2))
print("degrees(1.57) =", math.degrees(1.57))
print("radians(90) =", math.radians(90))
# Out:
# exp(4.0) = 2.718281828459045
# log(8.25) = 1.0
# log10(30, 50) = 1.0
# sqrt(6.7) = 2.0
# sin(PI / 2) = 1.0
# cos(PI / 2) = 6.123233995736766e-17
# tan(PI / 2) = 1.633123935319537e+16
# degrees(1.57) = 89.95437383553924
# radians(90) = 1.5707963267948966

# %% [markdown]
# Chapter 3_practice 3.1
